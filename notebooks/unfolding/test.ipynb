# %%
from experiments.unfolding.distributions import StandardLogPtPhiEta
import torch
import matplotlib.pyplot as plt

# %%
dist = StandardLogPtPhiEta(onshell_mass=0.1, pt_min=0.0, units=1.)

# %%
device = torch.device('cuda')
dtype = torch.float32
dist.coordinates.transforms[-1].init_unit(device, dtype)

# %%
samples = dist.sample((100000,4), device, dtype)

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
vars = ['E', 'px', 'py', 'pz']
for i in range(4):
    axs[i//2, i%2].hist(samples[:, i].cpu().numpy(), bins=100)
    axs[i//2, i%2].set_title(f'{vars[i]}')
plt.show()

# %%
samples = dist.coordinates.fourmomenta_to_x(samples)

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
vars = ['log pt', 'phi', 'eta', 'log m2']
for i in range(4):
    axs[i//2, i%2].hist(samples[:, i].cpu().numpy(), bins=100)
    axs[i//2, i%2].set_title(f'{vars[i]}')
plt.show()

# %%
torch.log(torch.tensor(0.01))
# Out:
# tensor(-4.6052)
